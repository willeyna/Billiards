# %%
from billiards import Billiards

# %%
x = np.array([1/np.sqrt(3), 0])
v = np.array([.1,-.2])
N = 1000

ball = Billiards(Billiards.ellipse_boundary, x, v, poincare = True, convexity=10)
for i in range(N):
    ball.bounce()

# %%
ball.plot_path()
# Out:
# Path figure saved as self.path_fig

# %%
ball.plot_poincare()
# Out:
# Poincare section figure saved as self.poincare_fig
